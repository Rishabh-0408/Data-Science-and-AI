# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh-0408/Data-Science-and-AI/blob/main/Day1_Basics_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name = "Rishabh"
Age = 22
Email = "rishabhsahu04098@gmail.com"
Designation = "Data science & ai"
print("My name is",Name,"I am ",Age,"old","My email id is",Email,"and my", Designation)
# Out:
# My name is Rishabh I am  22 old My email id is rishabhsahu04098@gmail.com and my Data science & ai

# %% [markdown]
# Agar comma use nahi karna hai to Formatting Use karte hai

# %%
print(f"{Name} {Age} {Email} {Designation}")
# Out:
# Rishabh 22 rishabhsahu04098@gmail.com Data science & ai

# %%
a = 5
b = 9
print(f"a+b = {a+b}")
# Out:
# a+b = 14

# %%
a,b,c = 10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %% [markdown]
# Q. Swap two numbers

# %%
a = 10
b = 20
swapped = a
a = b
b = swapped

print(a,b)
# Out:
# 20 10

# %% [markdown]
# without Third variable

# %%
a,b = 10,20
a,b = b,a
print(a,b)
# Out:
# 20 10

# %% [markdown]
# **Division Formula** -> Divident = divisor * quotient + Reminder

# %%
A = 12
B = 5

Quo = A//B
Reminder = A%B
Verify = B*Quo+Reminder
print(Verify)
# Out:
# 12

# %% [markdown]
# Q. Calculate Simple Interest

# %%
P = 10000
R = 6
T = 4
SI = (P*R*T)/100
print(SI)
# Out:
# 2400.0

# %% [markdown]
# Q. Convet Celcius in Fahrenheit

# %%
Celcius = 55
F = ((Celcius)*9/5)+32
print(F)
# Out:
# 131.0

# %% [markdown]
# Q. Calculate Area of Circle

# %%
Radius = 4
Area = 3.14*Radius**2
print(Area)
# Out:
# 50.24

# %% [markdown]
# Q. Calculate the Value of Hypotenuse

# %%
P = 4
B = 3
HypoSqar = P**2 + B**2
Hypo = HypoSqar**0.5
print(HypoSqar)
print(Hypo)
# Out:
# 25
# 5.0

# %% [markdown]
# Q. Create Two Variable and apply all Arithematic operations

# %%
a = 5
b = 10
print("a+b =",a+b)
print("a-b =",a-b)
print("a*b =",a*b)
print("a/b =",a/b)
print("a//b =",a//b)
print("a**b =",a**b)
# Out:
# a+b = 15
# a-b = -5
# a*b = 50
# a/b = 0.5
# a//b = 0
# a**b = 9765625

# %% [markdown]
# Q. find out the data type

# %%
a = 10
b = 10.5
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
# 10.0
# 10

# %% [markdown]
# Q. Change the type

# %%
print(float(a))
print(int(b))
# Out:
# 10.0
# 10

# %%
r = "30"
print(r + "20")
t = int(r)
print(t + 20 )
v ="apple"
#print(int(v))
# Out:
# 3020
# 50

# %%
Name = "Rishabh"
Course = "DS and AI"
Email = "Risahhabgamial.om"
Age = 22
print(f"My name is {Name} I have enrolled for {Course} my email id is {Email} and my age is {Age}")
# Out:
# My name is Rishabh I have enrolled for DS and AI my email id is Risahhabgamial.om and my age is 22

# %% [markdown]
# Q. Take input

# %%
Name = input("Enter your Name")
Age = input("Enter the Age")
Course = input("Enter the Course Details")
print("My name is", Name, "i am", Age,"year old and i have enrolled for", Course)
print(f"my name is {Name} my age is {Age}")
# Out:
# Enter your Namerishabh
# Enter the Age33
# Enter the Course Detailsda
# My name is rishabh i am 33 year old and i have enrolled for da
# my name is rishabh my age is 33

# %%
a = input("enter the num: ")
b = input("enter the num: ")
print("a+b=",int(a)+int(b))
# Out:
# enter the num: 5
# enter the num: 5
# a+b= 10

# %%
a = int(input("enter the num: "))
b = int(input("enter the num: "))
print("a+b=",a+b,"a*b=",a*b,"a/b=",a/b,"a//b=",a//b,"a-b=",a-b,"a**b=",a**b)
# Out:
# enter the num: 5
# enter the num: 5
# a+b= 10 a*b= 25 a/b= 1.0 a//b= 1 a-b= 0 a**b= 3125

# %%
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
# Out:
# False
# False
# True
# False

# %%
A = "a"
B = "b"
print(A>B)
print(A<B)
print(A==B)
print(A!=B)

A = "apple"
B = "apple"
print(A>B)
print(A<B)
print(A==B)
print(A!=B)

A = "apple"
B = "Apple"
print(A>B)
print(A<B)
print(A==B)
print(A!=B)
# Out:
# False
# True
# False
# True
# False
# False
# True
# False
# True
# False
# False
# True
